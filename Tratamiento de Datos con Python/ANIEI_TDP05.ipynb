# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/omarmendoza564/datos/main/datos/casoscovid20201101.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ORIGEN               200 non-null    int64
#  1   SEXO                 200 non-null    object
#  2   ENTIDAD              200 non-null    object
#  3   FECHA_INGRESO        200 non-null    object
#  4   INTUBADO             200 non-null    int64
#  5   NEUMONIA             200 non-null    int64
#  6   EDAD                 200 non-null    int64
#  7   NACIONALIDAD         200 non-null    object
#  8   EMBARAZO             200 non-null    int64
#  9   DIABETES             200 non-null    int64
#  10  EPOC                 200 non-null    int64
#  11  ASMA                 200 non-null    int64
#  12  INMUSUPR             200 non-null    int64
#  13  HIPERTENSION         200 non-null    int64
#  14  CARDIOVASCULAR       200 non-null    int64
# ...

# %%
df.dtypes
# Out:
# ORIGEN                  int64
# SEXO                   object
# ENTIDAD                object
# FECHA_INGRESO          object
# INTUBADO                int64
# NEUMONIA                int64
# EDAD                    int64
# NACIONALIDAD           object
# EMBARAZO                int64
# DIABETES                int64
# EPOC                    int64
# ASMA                    int64
# INMUSUPR                int64
# HIPERTENSION            int64
# CARDIOVASCULAR          int64
# OBESIDAD                int64
# RENAL_CRONICA           int64
# TABAQUISMO              int64
# RESULTADO_LAB           int64
# CLASIFICACION_FINAL     int64
# dtype: object

# %%
df.shape
# Out:
# (200, 20)

# %%
df
# Out:
#      ORIGEN    SEXO           ENTIDAD        FECHA_INGRESO  INTUBADO  \
# 0         1   MUJER           Sinaloa  2020-06-11 00:00:00         2
# 1         1   MUJER  Ciudad de México  2020-05-23 00:00:00        97
# 2         2   MUJER         Zacatecas  2020-01-05 00:00:00         2
# 3         1  HOMBRE        Guanajuato  2020-06-24 00:00:00        97
# 4         2  HOMBRE  Ciudad de México  2020-06-08 00:00:00        97
# ..      ...     ...               ...                  ...       ...
# 195       1  HOMBRE          Veracruz  2020-01-28 00:00:00        97
# 196       1   MUJER           Nayarit  2020-04-01 00:00:00        97
# 197       1  HOMBRE           Sinaloa  2020-05-02 00:00:00         2
# 198       1   MUJER          Veracruz  2020-03-25 00:00:00         2
# 199       1  HOMBRE           Sinaloa  2020-05-27 00:00:00        97
#
#      NEUMONIA  EDAD NACIONALIDAD  EMBARAZO  DIABETES  EPOC  ASMA  INMUSUPR  \
# ...

# %%
df.head(10)
# Out:
#    ORIGEN    SEXO           ENTIDAD        FECHA_INGRESO  INTUBADO  NEUMONIA  \
# 0       1   MUJER           Sinaloa  2020-06-11 00:00:00         2         1
# 1       1   MUJER  Ciudad de México  2020-05-23 00:00:00        97         2
# 2       2   MUJER         Zacatecas  2020-01-05 00:00:00         2         2
# 3       1  HOMBRE        Guanajuato  2020-06-24 00:00:00        97         2
# 4       2  HOMBRE  Ciudad de México  2020-06-08 00:00:00        97         2
# 5       1   MUJER           Jalisco  2020-04-03 00:00:00        97         2
# 6       1   MUJER  Ciudad de México  2020-07-02 00:00:00        97         2
# 7       1   MUJER  Ciudad de México  2020-03-05 00:00:00        97         2
# 8       2  HOMBRE  Ciudad de México  2020-05-26 00:00:00        97         2
# 9       2   MUJER   San Luis Potosí  2020-06-13 00:00:00        97         2
#
#    EDAD NACIONALIDAD  EMBARAZO  DIABETES  EPOC  ASMA  INMUSUPR  HIPERTENSION  \
# ...

# %%
df.tail(10)
# Out:
#      ORIGEN    SEXO           ENTIDAD        FECHA_INGRESO  INTUBADO  \
# 190       2  HOMBRE        Nuevo León  2020-04-01 00:00:00        97
# 191       1  HOMBRE         Querétaro  2020-06-22 00:00:00         2
# 192       2  HOMBRE  Ciudad de México  2020-03-25 00:00:00        97
# 193       1  HOMBRE        Guanajuato  2020-06-10 00:00:00         2
# 194       1  HOMBRE        Guanajuato  2020-03-31 00:00:00        97
# 195       1  HOMBRE          Veracruz  2020-01-28 00:00:00        97
# 196       1   MUJER           Nayarit  2020-04-01 00:00:00        97
# 197       1  HOMBRE           Sinaloa  2020-05-02 00:00:00         2
# 198       1   MUJER          Veracruz  2020-03-25 00:00:00         2
# 199       1  HOMBRE           Sinaloa  2020-05-27 00:00:00        97
#
#      NEUMONIA  EDAD NACIONALIDAD  EMBARAZO  DIABETES  EPOC  ASMA  INMUSUPR  \
# 190         2    24     MEXICANA        97         2     2     2         2
# ...

# %%
df.describe()
# Out:
#            ORIGEN    INTUBADO    NEUMONIA        EDAD    EMBARAZO    DIABETES  \
# count  200.000000  200.000000  200.000000  200.000000  200.000000  200.000000
# mean     1.535000   74.665000   11.030000   42.555000   49.490000    2.355000
# std      0.500025   40.495087   28.575899   18.961929   47.659701    6.805184
# min      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      1.000000   97.000000    2.000000   29.000000    2.000000    2.000000
# 50%      2.000000   97.000000    2.000000   41.000000   49.500000    2.000000
# 75%      2.000000   97.000000    2.000000   55.000000   97.000000    2.000000
# max      2.000000   99.000000   99.000000   86.000000   98.000000   98.000000
#
#              EPOC        ASMA    INMUSUPR  HIPERTENSION  CARDIOVASCULAR  \
# count  200.000000  200.000000  200.000000     200.00000      200.000000
# mean     2.455000    2.460000    2.460000       2.29500        2.465000
# ...

# %%
df.EDAD.describe()
# Out:
# count    200.000000
# mean      42.555000
# std       18.961929
# min        1.000000
# 25%       29.000000
# 50%       41.000000
# 75%       55.000000
# max       86.000000
# Name: EDAD, dtype: float64

# %%
df.EDAD[9:19:2]
# Out:
# 9     33
# 11    13
# 13    30
# 15    58
# 17    74
# Name: EDAD, dtype: int64

# %%
df[9:19:2]
# Out:
#     ORIGEN    SEXO           ENTIDAD        FECHA_INGRESO  INTUBADO  NEUMONIA  \
# 9        2   MUJER   San Luis Potosí  2020-06-13 00:00:00        97         2
# 11       1   MUJER           Jalisco  2020-02-18 00:00:00        97        99
# 13       2   MUJER  Estado de México  2020-05-20 00:00:00        97         2
# 15       1  HOMBRE           Jalisco  2020-02-10 00:00:00         2         1
# 17       2  HOMBRE           Sinaloa  2020-03-20 00:00:00        97         2
#
#     EDAD NACIONALIDAD  EMBARAZO  DIABETES  EPOC  ASMA  INMUSUPR  HIPERTENSION  \
# 9     33     MEXICANA         2         2     2     2         2             2
# 11    13     MEXICANA         2         2     2     2         2             2
# 13    30     MEXICANA         2         2     2     1         2             2
# 15    58     MEXICANA        97         2     2     2         2             2
# 17    74     MEXICANA        97         1     2     2         2             1
#
# ...

# %%
df[['EDAD', 'SEXO', 'ENTIDAD', 'RESULTADO_LAB']]
# Out:
#      EDAD    SEXO           ENTIDAD  RESULTADO_LAB
# 0      68   MUJER           Sinaloa              1
# 1      33   MUJER  Ciudad de México              1
# 2      52   MUJER         Zacatecas              2
# 3      48  HOMBRE        Guanajuato              1
# 4      43  HOMBRE  Ciudad de México              1
# ..    ...     ...               ...            ...
# 195    27  HOMBRE          Veracruz             97
# 196    28   MUJER           Nayarit             97
# 197    30  HOMBRE           Sinaloa              1
# 198    53   MUJER          Veracruz              2
# 199    41  HOMBRE           Sinaloa              1
#
# [200 rows x 4 columns]

# %%
df[9:19][['EDAD', 'SEXO', 'ENTIDAD', 'RESULTADO_LAB']]
# Out:
#     EDAD    SEXO           ENTIDAD  RESULTADO_LAB
# 9     33   MUJER   San Luis Potosí              1
# 10    45  HOMBRE           Tabasco              1
# 11    13   MUJER           Jalisco             97
# 12    42   MUJER   Baja California              1
# 13    30   MUJER  Estado de México              1
# 14    59  HOMBRE         Querétaro              2
# 15    58  HOMBRE           Jalisco              2
# 16    28  HOMBRE          Veracruz             97
# 17    74  HOMBRE           Sinaloa              2
# 18    63  HOMBRE  Ciudad de México              1

# %%
df.loc[9:19,'SEXO':'EDAD']
# Out:
#       SEXO           ENTIDAD        FECHA_INGRESO  INTUBADO  NEUMONIA  EDAD
# 9    MUJER   San Luis Potosí  2020-06-13 00:00:00        97         2    33
# 10  HOMBRE           Tabasco  2020-05-25 00:00:00        97         2    45
# 11   MUJER           Jalisco  2020-02-18 00:00:00        97        99    13
# 12   MUJER   Baja California  2020-05-25 00:00:00        97         2    42
# 13   MUJER  Estado de México  2020-05-20 00:00:00        97         2    30
# 14  HOMBRE         Querétaro  2020-02-18 00:00:00        97         2    59
# 15  HOMBRE           Jalisco  2020-02-10 00:00:00         2         1    58
# 16  HOMBRE          Veracruz  2020-03-27 00:00:00        97         2    28
# 17  HOMBRE           Sinaloa  2020-03-20 00:00:00        97         2    74
# 18  HOMBRE  Ciudad de México  2020-06-29 00:00:00        97         2    63
# 19  HOMBRE           Durango  2020-03-13 00:00:00        97         2    65

# %%
df.loc[9:19,['SEXO','EDAD','INTUBADO', 'ENTIDAD']]
# Out:
#       SEXO  EDAD  INTUBADO           ENTIDAD
# 9    MUJER    33        97   San Luis Potosí
# 10  HOMBRE    45        97           Tabasco
# 11   MUJER    13        97           Jalisco
# 12   MUJER    42        97   Baja California
# 13   MUJER    30        97  Estado de México
# 14  HOMBRE    59        97         Querétaro
# 15  HOMBRE    58         2           Jalisco
# 16  HOMBRE    28        97          Veracruz
# 17  HOMBRE    74        97           Sinaloa
# 18  HOMBRE    63        97  Ciudad de México
# 19  HOMBRE    65        97           Durango

# %%
df.loc[[10, 15, 19],['SEXO','EDAD','INTUBADO', 'ENTIDAD']]
# Out:
#       SEXO  EDAD  INTUBADO  ENTIDAD
# 10  HOMBRE    45        97  Tabasco
# 15  HOMBRE    58         2  Jalisco
# 19  HOMBRE    65        97  Durango

# %%
df.loc[[10, 15, 19],'EDAD':]
# Out:
#     EDAD NACIONALIDAD  EMBARAZO  DIABETES  EPOC  ASMA  INMUSUPR  HIPERTENSION  \
# 10    45     MEXICANA        97         2     2     2         2             2
# 15    58     MEXICANA        97         2     2     2         2             2
# 19    65     MEXICANA        97         2     2     2         2             2
#
#     CARDIOVASCULAR  OBESIDAD  RENAL_CRONICA  TABAQUISMO  RESULTADO_LAB  \
# 10               2         1              2           2              1
# 15               2         2              2           2              2
# 19               2         2              2           2             97
#
#     CLASIFICACION_FINAL
# 10                    3
# 15                    7
# 19                    6

# %%
df.loc[[10, 15, 19],'EDAD'::2]
# Out:
#     EDAD  EMBARAZO  EPOC  INMUSUPR  CARDIOVASCULAR  RENAL_CRONICA  \
# 10    45        97     2         2               2              2
# 15    58        97     2         2               2              2
# 19    65        97     2         2               2              2
#
#     RESULTADO_LAB
# 10              1
# 15              2
# 19             97

# %%
df.iloc[[10, 15, 19],6::2]
# Out:
#     EDAD  EMBARAZO  EPOC  INMUSUPR  CARDIOVASCULAR  RENAL_CRONICA  \
# 10    45        97     2         2               2              2
# 15    58        97     2         2               2              2
# 19    65        97     2         2               2              2
#
#     RESULTADO_LAB
# 10              1
# 15              2
# 19             97

# %%
#Filtros
df[df['EDAD']==30]
# Out:
#      ORIGEN    SEXO           ENTIDAD        FECHA_INGRESO  INTUBADO  \
# 13        2   MUJER  Estado de México  2020-05-20 00:00:00        97
# 43        2   MUJER           Sinaloa  2020-04-02 00:00:00        97
# 55        2  HOMBRE  Estado de México  2020-03-09 00:00:00        97
# 90        1   MUJER    Aguascalientes  2020-03-17 00:00:00        97
# 100       1  HOMBRE        Tamaulipas  2020-03-26 00:00:00        97
# 109       1   MUJER           Yucatán  2020-03-25 00:00:00        97
# 142       2  HOMBRE            Sonora  2020-06-02 00:00:00        97
# 188       2   MUJER        Nuevo León  2020-03-27 00:00:00        97
# 197       1  HOMBRE           Sinaloa  2020-05-02 00:00:00         2
#
#      NEUMONIA  EDAD NACIONALIDAD  EMBARAZO  DIABETES  EPOC  ASMA  INMUSUPR  \
# 13          2    30     MEXICANA         2         2     2     1         2
# 43          2    30     MEXICANA         2         2     2     2         2
# ...

# %%
#Filtros
df[50:][df['EDAD']==30]
# Out:
# C:\Users\joseg\AppData\Local\Temp\ipykernel_18500\2193967835.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[50:][df['EDAD']==30]
#      ORIGEN    SEXO           ENTIDAD        FECHA_INGRESO  INTUBADO  \
# 55        2  HOMBRE  Estado de México  2020-03-09 00:00:00        97
# 90        1   MUJER    Aguascalientes  2020-03-17 00:00:00        97
# 100       1  HOMBRE        Tamaulipas  2020-03-26 00:00:00        97
# 109       1   MUJER           Yucatán  2020-03-25 00:00:00        97
# 142       2  HOMBRE            Sonora  2020-06-02 00:00:00        97
# 188       2   MUJER        Nuevo León  2020-03-27 00:00:00        97
# 197       1  HOMBRE           Sinaloa  2020-05-02 00:00:00         2
#
#      NEUMONIA  EDAD NACIONALIDAD  EMBARAZO  DIABETES  EPOC  ASMA  INMUSUPR  \
# 55          2    30     MEXICANA        97         2     2     2         2
# 90          2    30     MEXICANA        98         2     2     2         2
# ...

# %%
df[df['SEXO']=='MUJER']
# Out:
#      ORIGEN   SEXO           ENTIDAD        FECHA_INGRESO  INTUBADO  NEUMONIA  \
# 0         1  MUJER           Sinaloa  2020-06-11 00:00:00         2         1
# 1         1  MUJER  Ciudad de México  2020-05-23 00:00:00        97         2
# 2         2  MUJER         Zacatecas  2020-01-05 00:00:00         2         2
# 5         1  MUJER           Jalisco  2020-04-03 00:00:00        97         2
# 6         1  MUJER  Ciudad de México  2020-07-02 00:00:00        97         2
# ..      ...    ...               ...                  ...       ...       ...
# 186       2  MUJER           Yucatán  2020-03-31 00:00:00        97         2
# 187       1  MUJER        Guanajuato  2020-02-26 00:00:00        97        99
# 188       2  MUJER        Nuevo León  2020-03-27 00:00:00        97         2
# 196       1  MUJER           Nayarit  2020-04-01 00:00:00        97         2
# 198       1  MUJER          Veracruz  2020-03-25 00:00:00         2         2
#
# ...

# %%
filtro_mujer = df['SEXO']=='MUJER'
type(filtro_mujer)
# Out:
# pandas.core.series.Series

# %%
df[filtro_mujer]
# Out:
#      ORIGEN   SEXO           ENTIDAD        FECHA_INGRESO  INTUBADO  NEUMONIA  \
# 0         1  MUJER           Sinaloa  2020-06-11 00:00:00         2         1
# 1         1  MUJER  Ciudad de México  2020-05-23 00:00:00        97         2
# 2         2  MUJER         Zacatecas  2020-01-05 00:00:00         2         2
# 5         1  MUJER           Jalisco  2020-04-03 00:00:00        97         2
# 6         1  MUJER  Ciudad de México  2020-07-02 00:00:00        97         2
# ..      ...    ...               ...                  ...       ...       ...
# 186       2  MUJER           Yucatán  2020-03-31 00:00:00        97         2
# 187       1  MUJER        Guanajuato  2020-02-26 00:00:00        97        99
# 188       2  MUJER        Nuevo León  2020-03-27 00:00:00        97         2
# 196       1  MUJER           Nayarit  2020-04-01 00:00:00        97         2
# 198       1  MUJER          Veracruz  2020-03-25 00:00:00         2         2
#
# ...

# %%
(df['SEXO']=='MUJER') & (df['EDAD']>=60)
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 195    False
# 196    False
# 197    False
# 198    False
# 199    False
# Length: 200, dtype: bool

# %%
filro_mas_60 = df['EDAD']>=60

# %%
df[(filtro_mujer) & filro_mas_60]
# Out:
#      ORIGEN   SEXO           ENTIDAD        FECHA_INGRESO  INTUBADO  NEUMONIA  \
# 0         1  MUJER           Sinaloa  2020-06-11 00:00:00         2         1
# 5         1  MUJER           Jalisco  2020-04-03 00:00:00        97         2
# 6         1  MUJER  Ciudad de México  2020-07-02 00:00:00        97         2
# 20        1  MUJER         Michoacán  2020-03-30 00:00:00         2         2
# 36        1  MUJER          Veracruz  2020-03-17 00:00:00        97         2
# 40        2  MUJER           Chiapas  2020-05-29 00:00:00        97         2
# 59        2  MUJER        Tamaulipas  2020-05-13 00:00:00        97         2
# 60        1  MUJER          Guerrero  2020-06-08 00:00:00         1         1
# 63        2  MUJER   San Luis Potosí  2020-03-31 00:00:00        97         2
# 76        1  MUJER           Chiapas  2020-05-15 00:00:00         2         2
# 80        1  MUJER          Veracruz  2020-01-17 00:00:00        97        99
# ...

# %%
df[filro_mas_60]
# Out:
#      ORIGEN    SEXO           ENTIDAD        FECHA_INGRESO  INTUBADO  \
# 0         1   MUJER           Sinaloa  2020-06-11 00:00:00         2
# 5         1   MUJER           Jalisco  2020-04-03 00:00:00        97
# 6         1   MUJER  Ciudad de México  2020-07-02 00:00:00        97
# 17        2  HOMBRE           Sinaloa  2020-03-20 00:00:00        97
# 18        2  HOMBRE  Ciudad de México  2020-06-29 00:00:00        97
# 19        2  HOMBRE           Durango  2020-03-13 00:00:00        97
# 20        1   MUJER         Michoacán  2020-03-30 00:00:00         2
# 28        1  HOMBRE        Nuevo León  2020-03-30 00:00:00        97
# 36        1   MUJER          Veracruz  2020-03-17 00:00:00        97
# 38        2  HOMBRE           Tabasco  2020-03-27 00:00:00        97
# 39        2  HOMBRE         Zacatecas  2020-05-08 00:00:00         2
# 40        2   MUJER           Chiapas  2020-05-29 00:00:00        97
# 59        2   MUJER        Tamaulipas  2020-05-13 00:00:00        97
# ...

# %%
df[filro_mas_60].count()
# Out:
# ORIGEN                 37
# SEXO                   37
# ENTIDAD                37
# FECHA_INGRESO          37
# INTUBADO               37
# NEUMONIA               37
# EDAD                   37
# NACIONALIDAD           37
# EMBARAZO               37
# DIABETES               37
# EPOC                   37
# ASMA                   37
# INMUSUPR               37
# HIPERTENSION           37
# CARDIOVASCULAR         37
# OBESIDAD               37
# RENAL_CRONICA          37
# TABAQUISMO             37
# RESULTADO_LAB          37
# CLASIFICACION_FINAL    37
# dtype: int64

# %%
df[filtro_mujer & filro_mas_60].count()
# Out:
# ORIGEN                 21
# SEXO                   21
# ENTIDAD                21
# FECHA_INGRESO          21
# INTUBADO               21
# NEUMONIA               21
# EDAD                   21
# NACIONALIDAD           21
# EMBARAZO               21
# DIABETES               21
# EPOC                   21
# ASMA                   21
# INMUSUPR               21
# HIPERTENSION           21
# CARDIOVASCULAR         21
# OBESIDAD               21
# RENAL_CRONICA          21
# TABAQUISMO             21
# RESULTADO_LAB          21
# CLASIFICACION_FINAL    21
# dtype: int64

# %%
df[filtro_mujer & filro_mas_60][['EDAD', 'ENTIDAD']]
# Out:
#      EDAD           ENTIDAD
# 0      68           Sinaloa
# 5      61           Jalisco
# 6      60  Ciudad de México
# 20     71         Michoacán
# 36     61          Veracruz
# 40     64           Chiapas
# 59     84        Tamaulipas
# 60     81          Guerrero
# 63     85   San Luis Potosí
# 76     75           Chiapas
# 80     85          Veracruz
# 89     63  Estado de México
# 102    77         Chihuahua
# 108    64           Chiapas
# 113    80          Coahuila
# 130    68           Jalisco
# 141    80          Veracruz
# 149    76          Guerrero
# 151    66           Sinaloa
# 177    86        Guanajuato
# 181    82  Ciudad de México

# %%
df[df.ENTIDAD.isin(['Guerrero', 'Sinaloa','Jalisco'])]
# Out:
#      ORIGEN    SEXO   ENTIDAD        FECHA_INGRESO  INTUBADO  NEUMONIA  EDAD  \
# 0         1   MUJER   Sinaloa  2020-06-11 00:00:00         2         1    68
# 5         1   MUJER   Jalisco  2020-04-03 00:00:00        97         2    61
# 11        1   MUJER   Jalisco  2020-02-18 00:00:00        97        99    13
# 15        1  HOMBRE   Jalisco  2020-02-10 00:00:00         2         1    58
# 17        2  HOMBRE   Sinaloa  2020-03-20 00:00:00        97         2    74
# 32        2  HOMBRE   Jalisco  2020-03-30 00:00:00        97         2    28
# 43        2   MUJER   Sinaloa  2020-04-02 00:00:00        97         2    30
# 50        1  HOMBRE  Guerrero  2020-07-02 00:00:00        97         2    52
# 60        1   MUJER  Guerrero  2020-06-08 00:00:00         1         1    81
# 65        1   MUJER  Guerrero  2020-03-31 00:00:00        97         2    39
# 68        1  HOMBRE  Guerrero  2020-04-30 00:00:00         2         1    67
# ...

# %%
df[(df.ENTIDAD.isin(['Guerrero', 'Sinaloa','Jalisco'])) & filtro_mujer]
# Out:
#      ORIGEN   SEXO   ENTIDAD        FECHA_INGRESO  INTUBADO  NEUMONIA  EDAD  \
# 0         1  MUJER   Sinaloa  2020-06-11 00:00:00         2         1    68
# 5         1  MUJER   Jalisco  2020-04-03 00:00:00        97         2    61
# 11        1  MUJER   Jalisco  2020-02-18 00:00:00        97        99    13
# 43        2  MUJER   Sinaloa  2020-04-02 00:00:00        97         2    30
# 60        1  MUJER  Guerrero  2020-06-08 00:00:00         1         1    81
# 65        1  MUJER  Guerrero  2020-03-31 00:00:00        97         2    39
# 104       2  MUJER  Guerrero  2020-05-18 00:00:00        97         2    28
# 130       2  MUJER   Jalisco  2020-05-09 00:00:00        97         2    68
# 149       2  MUJER  Guerrero  2020-06-20 00:00:00        97         2    76
# 151       1  MUJER   Sinaloa  2020-06-01 00:00:00         2         1    66
# 182       2  MUJER   Jalisco  2020-03-26 00:00:00        97         2    51
#
# ...
